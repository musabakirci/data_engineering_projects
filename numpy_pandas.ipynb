# %%
# %cd /content/sample_data
# Out:
# /content/sample_data

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('salary_xl.xlsx')

# %%
data.head()
# Out:
#    Age  Gender Education Level          Job Title  Years of Experience  Salary
# 0   32    Male      Bachelor's  Software Engineer                  5.0   90000
# 1   28  Female        Master's       Data Analyst                  3.0   65000
# 2   45    Male             PhD     Senior Manager                 15.0  150000
# 3   36  Female      Bachelor's    Sales Associate                  7.0   60000
# 4   52    Male        Master's           Director                 20.0  200000

# %%
data.shape
# Out:
# (1000, 6)

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      523
# Female    477
# Name: count, dtype: int64

# %%
data['Gender_say']=data['Gender'].map({'Male':1,'Female':0})

# %%
data.head()
# Out:
#    Age          Job Title  Years of Experience  Salary  Gender_say  \
# 0   32  Software Engineer                  5.0   90000           1
# 1   28       Data Analyst                  3.0   65000           0
# 2   45     Senior Manager                 15.0  150000           1
# 3   36    Sales Associate                  7.0   60000           0
# 4   52           Director                 20.0  200000           1
#
#    Education Level Say
# 0                    1
# 1                    2
# 2                    3
# 3                    1
# 4                    2

# %%
data.drop('Gender',axis=1,inplace=True)

# %%
data['Education Level'].value_counts()
# Out:
# Education Level
# Bachelor's           614
# Master's             245
# PhD                  128
# Bachelor's Degree      9
# Master's Degree        4
# Name: count, dtype: int64

# %%
data['Education Level Say']=data['Education Level'].map({'Bachelor\'s':1,'Master\'s':2,
                                                         'PhD':3, 'Bachelor\'s Degree':1,'Master\'s Degree':2})

# %%
data['Education Level Say'].value_counts()
# Out:
# Education Level Say
# 1    623
# 2    249
# 3    128
# Name: count, dtype: int64

# %%
data.drop('Education Level',axis=1,inplace=True)

# %%
data.head()
# Out:
#    Age          Job Title  Years of Experience  Salary  Gender_say  \
# 0   32  Software Engineer                  5.0   90000           1
# 1   28       Data Analyst                  3.0   65000           0
# 2   45     Senior Manager                 15.0  150000           1
# 3   36    Sales Associate                  7.0   60000           0
# 4   52           Director                 20.0  200000           1
#
#    Education Level Say
# 0                    1
# 1                    2
# 2                    3
# 3                    1
# 4                    2

# %%
data['Job Title'].value_counts()
# Out:
# Job Title
# Data Analyst                      210
# Software Engineer                 174
# Data Scientist                    134
# Product Manager                   115
# Director of Marketing              12
#                                  ...
# Junior Social Media Specialist      1
# Junior Operations Coordinator       1
# Senior HR Specialist                1
# Director of HR                      1
# Junior Financial Advisor            1
# Name: count, Length: 174, dtype: int64

# %%
isler=['Data Analyst','Software Engineer','Data Scientist','Product Manager','Director of Marketing']

# %%
silinecek_satirlar=[]
for i in range(data.shape[0]):
  if data['Job Title'].iloc[i]  not in isler:
    silinecek_satirlar.append(i)

# %%
len(silinecek_satirlar)
# Out:
# 355

# %%
data.drop(silinecek_satirlar,axis=0,inplace=True)

# %%
data.shape
# Out:
# (645, 6)
